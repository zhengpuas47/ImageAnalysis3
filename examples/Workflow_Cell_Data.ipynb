# %% [markdown]
# # Workflow for Class Cell_Data
#
# by Pu Zheng
#
# 2018.10.11

# %% [markdown]
# ## 0.imports

# %%
# %run "C:\Users\Pu Zheng\Documents\Startup_py3.py"
sys.path.append(r"C:\Users\Pu Zheng\Documents")

import ImageAnalysis3 as ia
# %matplotlib notebook

from ImageAnalysis3 import get_img_info, visual_tools, corrections

# %% [markdown]
# ### 0.1 old info imports, just for checking purposes

# %%
# master folder for this dataset:
master_folder = r'Z:/20180911-IMR90_whole-chr21'
# get Folders, Field-of-views
folders, fovs = ia.get_img_info.get_folders(master_folder, feature='H', verbose=True)
# analysis
analysis_folder=master_folder+os.sep+'Analysis'
# Out:
# Get Folder Names: (ia.get_img_info.get_folders)
# - Number of folders: 127
# - Number of field of views: 65

# %% [markdown]
# ## 1. Create Cell_Data item

# %%
reload(ia.get_img_info)
reload(ia.analysis)
reload(ia.corrections)
reload(ia.visual_tools)
reload(ia.classes)
# Out:
# <module 'ImageAnalysis3.classes' from 'C:\\Users\\Pu Zheng\\Documents\\ImageAnalysis3\\classes.py'>

# %% [markdown]
# ### 1.0 create cell_data class and load basic info

# %%
# specify initialization parameters:
param = {'data_folder':'Z:/20180911-IMR90_whole-chr21',
         'fov_id': 55,
         'cell_id': 22,
         'temp_folder': r'G:\Temp',
         'save_folder':r'Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu',
         'map_folder':r'Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\distmap',
         'correction_folder':r'Z:\20180911-IMR90_whole-chr21\Analysis\Corrections',
         };
# initialize cell_data class:
a = ia.classes.Cell_Data(param)

# load color_usage
a._load_color_info();
# load encoding_scheme
a._load_encoding_scheme();
# Out:
# Get Folder Names: (ia.get_img_info.get_folders)
# - Number of folders: 127
# - Number of field of views: 65
# - Importing csv file: Z:/20180911-IMR90_whole-chr21\Analysis\Color_Usage.csv
# - header: ['Hyb', '750', '647', '561', '488', '405']
# -- Hyb H0R0 exists in this data
# -- DAPI exists in hyb: H0R0
# -- 127 folders are found according to color-usage annotation.
# - Importing csv file: Z:/20180911-IMR90_whole-chr21\Analysis\Color_Usage.csv
# - header: ['Hyb', '750', '647', '561', '488', '405']
# -- Hyb H0R0 exists in this data
# -- DAPI exists in hyb: H0R0
# - Importing csv file: Z:/20180911-IMR90_whole-chr21\Analysis\Encoding_Scheme.csv
# -- hyb per group: 5
# -- region per group: 10
# -- colors: ['750', '647', '561']
# -- number of groups: [22, 22, 22]

# %% [markdown]
# ### 1.1 Load more info for cell

# %%
# load existing cell_info, dont run for the first time
a._load_from_file('cell_info')
# load segmentation
a._load_segmentation(_denoise_window=0);
# load drift info
drift = a._load_drift(_size=650, _dynamic=True)
# Out:
# - drift already exists for cell:22, skip

# %% [markdown]
# ### 1.2 Load and crop images from raw data

# %%
# load cropped unique images:
#unique_ims, unique_ids, unique_channels = a._load_images('unique', _verbose=True, _save=True)

# load cropped combo images:
combo_groups = a._crop_images('combo', _verbose=True)

# %% [markdown]
# ### 1.3 Save to file

# %%
#a._save_to_file('all') # save all

a._save_to_file('cell_info') # save all cell_info exclude images
#a._save_to_file('cell_info', _save_dic={'distance_zxy':a.distance_zxy}) # save specifically this variable

#a._save_to_file('unique') # save unique info into unique_rounds.npz

#a._save_to_file('combo') # save combo_groups into Harry's format
# Out:
# - Save cell_info to: Z:/20180911-IMR90_whole-chr21\Analysis\5x10\fov-1\cell-1\cell_info.pkl
# -- loading existing info from file: Z:/20180911-IMR90_whole-chr21\Analysis\5x10\fov-1\cell-1\cell_info.pkl
# -- information updated in cell_info.pkl: ['distance_reference']
# - Writing cell data to file: Z:/20180911-IMR90_whole-chr21\Analysis\5x10\fov-1\cell-1\cell_info.pkl

# %% [markdown]
# ### 1.4 Directly load from files

# %%
# unique
#a._load_from_file('unique', _overwrite=False)
# combo
a._load_from_file('combo', _overwrite=False)
# similar examples for combo and all
# Out:
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-0\channel-750\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-0\channel-647\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-0\channel-561\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-1\channel-750\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-1\channel-647\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-1\channel-561\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-2\channel-750\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-2\channel-647\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-2\channel-561\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-3\channel-750\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-3\channel-647\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-3\channel-561\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-4\channel-750\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-4\channel-647\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-4\channel-561\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-5\channel-750\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-5\channel-647\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-5\channel-561\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-6\channel-750\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-6\channel-647\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-6\channel-561\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-7\channel-750\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-7\channel-647\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-7\channel-561\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-8\channel-750\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-8\channel-647\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-8\channel-561\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-9\channel-750\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-9\channel-647\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-9\channel-561\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-10\channel-750\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-10\channel-647\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-10\channel-561\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-11\channel-750\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-11\channel-647\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-11\channel-561\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-12\channel-750\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-12\channel-647\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-12\channel-561\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-13\channel-750\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-13\channel-647\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-13\channel-561\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-14\channel-750\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-14\channel-647\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-14\channel-561\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-15\channel-750\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-15\channel-647\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-15\channel-561\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-16\channel-750\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-16\channel-647\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-16\channel-561\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-17\channel-750\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-17\channel-647\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-17\channel-561\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-18\channel-750\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-18\channel-647\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-18\channel-561\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-19\channel-750\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-19\channel-647\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-19\channel-561\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-20\channel-750\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-20\channel-647\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-20\channel-561\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-21\channel-750\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-21\channel-647\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-11\cell-10\group-21\channel-561\rounds.npz

# %% [markdown]
# ## 2. Generate and Pick chromosome

# %% [markdown]
# ### 2.1 generate and identify chromosome

# %%
# generate
a._generate_chromosome_image('combo')
# identify
a._identify_chromosomes();
# manually pick for only this cell
a._pick_chromosome_manual()

# then do manual picking and close the matplotlib notebook inferface.

# %% [markdown]
# ### 2.2 Update chromosome coordinate info

# %%
a._update_chromosome_from_file();
# Out:
# -- 2 loaded

# %% [markdown]
# ## 3. Fitting and picking spots for decoded images

# %% [markdown]
# ### 3.1 Load decoded images

# %%
a._load_from_file('decoded', _decoded_flag='diff')
print(len(a.decoded_ids))
# Out:
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-0\channel-750\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-0\channel-647\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-0\channel-561\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-1\channel-750\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-1\channel-647\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-1\channel-561\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-2\channel-750\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-2\channel-647\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-2\channel-561\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-3\channel-750\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-3\channel-647\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-3\channel-561\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-4\channel-750\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-4\channel-647\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-4\channel-561\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-5\channel-750\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-5\channel-647\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-5\channel-561\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-6\channel-750\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-6\channel-647\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-6\channel-561\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-7\channel-750\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-7\channel-647\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-7\channel-561\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-8\channel-750\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-8\channel-647\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-8\channel-561\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-9\channel-750\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-9\channel-647\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-9\channel-561\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-10\channel-750\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-10\channel-647\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-10\channel-561\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-11\channel-750\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-11\channel-647\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-11\channel-561\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-12\channel-750\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-12\channel-647\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-12\channel-561\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-13\channel-750\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-13\channel-647\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-13\channel-561\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-14\channel-750\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-14\channel-647\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-14\channel-561\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-15\channel-750\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-15\channel-647\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-15\channel-561\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-16\channel-750\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-16\channel-647\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-16\channel-561\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-17\channel-750\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-17\channel-647\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-17\channel-561\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-18\channel-750\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-18\channel-647\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-18\channel-561\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-19\channel-750\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-19\channel-647\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-19\channel-561\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-20\channel-750\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-20\channel-647\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-20\channel-561\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-21\channel-750\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-21\channel-647\rounds.npz
# -- loading combo from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-21\channel-561\rounds.npz
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-0\channel-750\diff\regions.npz
# --- decoded result matched for group:0, color:750
# --- kept ids: [5, 44, 82, 140, 203, 233, 276, 309, 412, 508]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-0\channel-647\diff\regions.npz
# --- decoded result matched for group:0, color:647
# --- kept ids: [6, 42, 83, 141, 201, 234, 274, 310, 413, 509]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-0\channel-561\diff\regions.npz
# --- decoded result matched for group:0, color:561
# --- kept ids: [4, 43, 84, 139, 202, 235, 275, 308, 414, 510]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-1\channel-750\diff\regions.npz
# --- decoded result matched for group:1, color:750
# --- kept ids: [8, 47, 85, 143, 206, 255, 279, 312, 415, 511]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-1\channel-647\diff\regions.npz
# --- decoded result matched for group:1, color:647
# --- kept ids: [9, 45, 86, 144, 204, 277, 313, 416, 488, 512]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-1\channel-561\diff\regions.npz
# --- decoded result matched for group:1, color:561
# --- kept ids: [7, 46, 87, 142, 205, 254, 278, 311, 417, 513]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-2\channel-750\diff\regions.npz
# --- decoded result matched for group:2, color:750
# --- kept ids: [11, 50, 88, 146, 209, 258, 282, 315, 418, 514]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-2\channel-647\diff\regions.npz
# --- decoded result matched for group:2, color:647
# --- kept ids: [12, 48, 89, 147, 207, 280, 316, 419, 491, 515]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-2\channel-561\diff\regions.npz
# --- decoded result matched for group:2, color:561
# --- kept ids: [10, 49, 90, 145, 208, 281, 314, 420, 489, 516]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-3\channel-750\diff\regions.npz
# --- decoded result matched for group:3, color:750
# --- kept ids: [14, 53, 91, 149, 212, 236, 318, 421, 490, 517]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-3\channel-647\diff\regions.npz
# --- decoded result matched for group:3, color:647
# --- kept ids: [15, 51, 92, 150, 210, 237, 283, 319, 422, 518]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-3\channel-561\diff\regions.npz
# --- decoded result matched for group:3, color:561
# --- kept ids: [13, 52, 93, 148, 211, 284, 317, 423, 492, 519]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-4\channel-750\diff\regions.npz
# --- decoded result matched for group:4, color:750
# --- kept ids: [17, 56, 94, 152, 215, 321, 424, 520, 577, 636]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-4\channel-647\diff\regions.npz
# --- decoded result matched for group:4, color:647
# --- kept ids: [18, 54, 95, 153, 213, 256, 322, 425, 521, 578]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-4\channel-561\diff\regions.npz
# --- decoded result matched for group:4, color:561
# --- kept ids: [16, 55, 96, 151, 214, 238, 257, 320, 426, 522]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-5\channel-750\diff\regions.npz
# --- decoded result matched for group:5, color:750
# --- kept ids: [20, 59, 97, 155, 218, 324, 427, 523, 580, 639]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-5\channel-647\diff\regions.npz
# --- decoded result matched for group:5, color:647
# --- kept ids: [21, 57, 98, 156, 216, 259, 325, 428, 524, 581]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-5\channel-561\diff\regions.npz
# --- decoded result matched for group:5, color:561
# --- kept ids: [19, 58, 99, 154, 217, 323, 429, 472, 525, 576]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-6\channel-750\diff\regions.npz
# --- decoded result matched for group:6, color:750
# --- kept ids: [23, 62, 100, 158, 239, 261, 285, 327, 493, 526]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-6\channel-647\diff\regions.npz
# --- decoded result matched for group:6, color:647
# --- kept ids: [24, 60, 101, 159, 219, 240, 286, 374, 494, 527]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-6\channel-561\diff\regions.npz
# --- decoded result matched for group:6, color:561
# --- kept ids: [22, 61, 102, 157, 220, 260, 326, 475, 528, 579]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-7\channel-750\diff\regions.npz
# --- decoded result matched for group:7, color:750
# --- kept ids: [26, 65, 103, 161, 352, 376, 449, 473, 529, 543]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-7\channel-647\diff\regions.npz
# --- decoded result matched for group:7, color:647
# --- kept ids: [27, 63, 104, 162, 447, 474, 556, 601, 622, 637]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-7\channel-561\diff\regions.npz
# --- decoded result matched for group:7, color:561
# --- kept ids: [25, 64, 105, 160, 241, 287, 375, 448, 495, 542]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-8\channel-750\diff\regions.npz
# --- decoded result matched for group:8, color:750
# --- kept ids: [29, 68, 106, 164, 355, 379, 452, 476, 532, 600]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-8\channel-647\diff\regions.npz
# --- decoded result matched for group:8, color:647
# --- kept ids: [30, 66, 107, 165, 450, 477, 559, 604, 625, 640]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-8\channel-561\diff\regions.npz
# --- decoded result matched for group:8, color:561
# --- kept ids: [28, 67, 108, 163, 244, 290, 498, 557, 623, 638]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-9\channel-750\diff\regions.npz
# --- decoded result matched for group:9, color:750
# --- kept ids: [32, 71, 109, 167, 242, 288, 330, 496, 546, 603]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-9\channel-647\diff\regions.npz
# --- decoded result matched for group:9, color:647
# --- kept ids: [69, 110, 168, 222, 243, 289, 328, 377, 497, 530]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-9\channel-561\diff\regions.npz
# --- decoded result matched for group:9, color:561
# --- kept ids: [31, 70, 111, 166, 378, 451, 545, 560, 626, 641]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-10\channel-750\diff\regions.npz
# --- decoded result matched for group:10, color:750
# --- kept ids: [112, 170, 221, 264, 342, 430, 462, 558, 583, 642]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-10\channel-647\diff\regions.npz
# --- decoded result matched for group:10, color:647
# --- kept ids: [72, 113, 171, 225, 262, 340, 353, 431, 544, 584]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-10\channel-561\diff\regions.npz
# --- decoded result matched for group:10, color:561
# --- kept ids: [114, 169, 223, 263, 329, 341, 432, 478, 531, 582]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-11\channel-750\diff\regions.npz
# --- decoded result matched for group:11, color:750
# --- kept ids: [115, 173, 224, 267, 345, 433, 465, 586, 624, 645]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-11\channel-647\diff\regions.npz
# --- decoded result matched for group:11, color:647
# --- kept ids: [75, 116, 174, 265, 343, 356, 434, 533, 547, 587]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-11\channel-561\diff\regions.npz
# --- decoded result matched for group:11, color:561
# --- kept ids: [117, 172, 226, 332, 354, 397, 481, 534, 585, 602]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-12\channel-750\diff\regions.npz
# --- decoded result matched for group:12, color:750
# --- kept ids: [35, 74, 118, 176, 245, 333, 549, 561, 606, 627]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-12\channel-647\diff\regions.npz
# --- decoded result matched for group:12, color:647
# --- kept ids: [33, 119, 177, 246, 292, 331, 380, 453, 480, 500]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-12\channel-561\diff\regions.npz
# --- decoded result matched for group:12, color:561
# --- kept ids: [34, 73, 120, 175, 266, 344, 357, 400, 435, 605]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-13\channel-750\diff\regions.npz
# --- decoded result matched for group:13, color:750
# --- kept ids: [121, 179, 291, 300, 358, 382, 455, 479, 499, 535]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-13\channel-647\diff\regions.npz
# --- decoded result matched for group:13, color:647
# --- kept ids: [122, 180, 301, 367, 390, 399, 562, 607, 628, 643]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-13\channel-561\diff\regions.npz
# --- decoded result matched for group:13, color:561
# --- kept ids: [123, 178, 247, 293, 381, 454, 548, 563, 629, 644]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-14\channel-750\diff\regions.npz
# --- decoded result matched for group:14, color:750
# --- kept ids: [124, 182, 294, 361, 366, 389, 398, 502, 538, 615]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-14\channel-647\diff\regions.npz
# --- decoded result matched for group:14, color:647
# --- kept ids: [125, 183, 304, 370, 393, 463, 565, 610, 631, 646]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-14\channel-561\diff\regions.npz
# --- decoded result matched for group:14, color:561
# --- kept ids: [126, 181, 365, 384, 464, 501, 566, 614, 632, 647]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-15\channel-750\diff\regions.npz
# --- decoded result matched for group:15, color:750
# --- kept ids: [127, 185, 303, 369, 385, 392, 401, 458, 482, 618]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-15\channel-647\diff\regions.npz
# --- decoded result matched for group:15, color:647
# --- kept ids: [36, 128, 186, 249, 295, 334, 383, 402, 466, 503]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-15\channel-561\diff\regions.npz
# --- decoded result matched for group:15, color:561
# --- kept ids: [129, 184, 250, 296, 368, 457, 467, 504, 551, 617]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-16\channel-750\diff\regions.npz
# --- decoded result matched for group:16, color:750
# --- kept ids: [38, 77, 130, 188, 248, 336, 552, 564, 609, 630]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-16\channel-647\diff\regions.npz
# --- decoded result matched for group:16, color:647
# --- kept ids: [78, 131, 189, 268, 346, 359, 437, 456, 483, 590]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-16\channel-561\diff\regions.npz
# --- decoded result matched for group:16, color:561
# --- kept ids: [37, 76, 132, 187, 269, 347, 360, 403, 438, 608]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-17\channel-750\diff\regions.npz
# --- decoded result matched for group:17, color:750
# --- kept ids: [133, 191, 227, 270, 348, 436, 443, 468, 589, 648]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-17\channel-647\diff\regions.npz
# --- decoded result matched for group:17, color:647
# --- kept ids: [134, 192, 228, 407, 459, 536, 550, 571, 594, 616]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-17\channel-561\diff\regions.npz
# --- decoded result matched for group:17, color:561
# --- kept ids: [135, 190, 229, 302, 335, 391, 408, 484, 537, 588]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-18\channel-750\diff\regions.npz
# --- decoded result matched for group:18, color:750
# --- kept ids: [136, 194, 230, 273, 351, 439, 570, 592, 596, 651]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-18\channel-647\diff\regions.npz
# --- decoded result matched for group:18, color:647
# --- kept ids: [137, 195, 231, 410, 486, 539, 553, 574, 597, 619]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-18\channel-561\diff\regions.npz
# --- decoded result matched for group:18, color:561
# --- kept ids: [138, 193, 232, 338, 442, 487, 540, 572, 591, 595]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-19\channel-750\diff\regions.npz
# --- decoded result matched for group:19, color:750
# --- kept ids: [41, 80, 197, 446, 471, 567, 573, 599, 612, 633]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-19\channel-647\diff\regions.npz
# --- decoded result matched for group:19, color:647
# --- kept ids: [81, 198, 271, 298, 349, 362, 405, 440, 469, 593]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-19\channel-561\diff\regions.npz
# --- decoded result matched for group:19, color:561
# --- kept ids: [196, 305, 363, 394, 406, 411, 445, 575, 598, 611]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-20\channel-750\diff\regions.npz
# --- decoded result matched for group:20, color:750
# --- kept ids: [200, 251, 339, 372, 388, 395, 404, 461, 555, 621]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-20\channel-647\diff\regions.npz
# --- decoded result matched for group:20, color:647
# --- kept ids: [39, 252, 307, 337, 386, 506, 568, 613, 634, 649]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-20\channel-561\diff\regions.npz
# --- decoded result matched for group:20, color:561
# --- kept ids: [40, 79, 199, 272, 350, 371, 441, 470, 507, 620]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-21\channel-750\diff\regions.npz
# --- decoded result matched for group:21, color:750
# --- kept ids: [1, 297, 306, 364, 409, 485, 505, 541]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-21\channel-647\diff\regions.npz
# --- decoded result matched for group:21, color:647
# --- kept ids: [444, 2, 373, 396]
# -- loading decoded result from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\group-21\channel-561\diff\regions.npz
# --- decoded result matched for group:21, color:561
# --- kept ids: [3, 253, 299, 387, 460, 554, 569, 635, 650]
# 651

# %% [markdown]
# ### 3.2 multi-fitting

# %%
cand_spots = a._multi_fitting(_type='decoded', _num_threads=6, _max_seed_count=6, _min_seed_count=3, _th_to_end=1e-7, _save=True)
#cand_spots = a._multi_fitting(_type='unique', _max_seed_count=6, _min_seed_count=3, _th_to_end=1e-6)
# Out:
# + Start multi-fitting for decoded images
# ++ start fitting decoded for fov:5, cell:0 with 6 threads
# ++ total time in fitting decoded: 823.7691106796265
# - Save cell_info to: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\cell_info.pkl
# -- loading existing info from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\cell_info.pkl
# -- information updated in cell_info.pkl: ['encoding_colors', 'encoding_group_nums', 'hyb_per_group', 'reg_per_group', 'decoded_spots']
# - Writing cell data to file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\cell_info.pkl

# %% [markdown]
# ### 3.3 picking spots by intensity

# %%
naive_picked_pts = a._naive_picking_spots('decoded', _save=False)
# Out:
# + Pick decoded spots for by brightness in fov:5, cell:0

# %% [markdown]
# #### 3.2.1 distance map for one chromosome

# %%
import matplotlib
from scipy.spatial.distance import pdist,squareform

chrom_id = 0;
print(f"chromosome id:{chrom_id}, coordinate:{a.chrom_coords[chrom_id]}");
# extract coordinates
coords_in_pxl = np.stack([s[1:4] for s in naive_picked_pts[chrom_id]]) # extract only coordnates 
# convert to nm
coords_in_nm = coords_in_pxl * a.distance_zxy
# calculate distance map
distmap = squareform(pdist(coords_in_nm))
# Out:
# chromosome id:0, coordinate:[ 13.72337963  84.79918981 110.20804398]

# %%
plt.figure()
plt.imshow(distmap, interpolation='nearest', cmap=matplotlib.cm.seismic_r, vmin=200, vmax=1000)
plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# ### 3.4 dynamic picking spots

# %%
dynamic_picked_pts = a._dynamic_picking_spots('decoded', _w_dist=2)
# Out:
# + Pick decoded spots for by brightness in fov:5, cell:0
# - Save cell_info to: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\cell_info.pkl
# -- loading existing info from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\cell_info.pkl
# -- information updated in cell_info.pkl: ['picked_decoded_spots']
# - Writing cell data to file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\cell_info.pkl

# %%
distmaps = a._generate_distance_map('decoded',_limits=[200,1000])
# Out:
# ++ generate decoded dist-map for fov:5, cell:0, chrom:0
# <img src="data:image/png;base64,..." width="639.9999861283738">
# ++ generate decoded dist-map for fov:5, cell:0, chrom:1
# <img src="data:image/png;base64,..." width="639.9999861283738">
# - Save cell_info to: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\cell_info.pkl
# -- loading existing info from file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\cell_info.pkl
# -- information updated in cell_info.pkl: ['decoded_distance_map']
# - Writing cell data to file: Z:\20180911-IMR90_whole-chr21\Analysis\dense-gpu\fov-5\cell-0\cell_info.pkl

# %% [markdown]
# ## 4. Fitting and picking spots for unique images

# %% [markdown]
# ### 4.1 Load decoded images
#
# included in previous loading process

# %% [markdown]
# ### 4.2 multi-fitting

# %%
cand_spots = a._multi_fitting(_type='unique', _max_seed_count=6, _min_seed_count=3, _th_to_end=1e-6)
# Out:
# + Start multi-fitting for unique images
# ++ start fitting unique for fov:0, cell:0 with 5 threads
# ++ total time in fitting: 3344.830055952072
# - Save cell_info to: Z:/20180911-IMR90_whole-chr21\Analysis\5x10\fov-0\cell-0\cell_info.pkl
# -- loading existing info from file: Z:/20180911-IMR90_whole-chr21\Analysis\5x10\fov-0\cell-0\cell_info.pkl
# -- information updated in cell_info.pkl: ['unique_spots', 'unique_spots']
# - Writing cell data to file: Z:/20180911-IMR90_whole-chr21\Analysis\5x10\fov-0\cell-0\cell_info.pkl

# %% [markdown]
# ### 4.3 picking spots by intensity

# %%
naive_picked_pts = a._naive_picking_spots('unique', _save=False)
# Out:
# + Pick unique spots for by brightness in fov:0, cell:0

# %% [markdown]
# #### 4.2.1 distance map for one chromosome

# %%
import matplotlib
from scipy.spatial.distance import pdist,squareform

chrom_id = 0;
print(f"chromosome id:{chrom_id}, coordinate:{a.chrom_coords[chrom_id]}");
# extract coordinates
coords_in_pxl = np.stack([s[1:4] for s in naive_picked_pts[chrom_id]]) # extract only coordnates 
# convert to nm
coords_in_nm = coords_in_pxl * a.distance_zxy
# calculate distance map
distmap = squareform(pdist(coords_in_nm))
# Out:
# chromosome id:0, coordinate:[ 18.40221015  78.27206554 103.93315194]

# %%
plt.figure()
plt.imshow(distmap, interpolation='nearest', cmap=matplotlib.cm.seismic_r, vmin=200, vmax=1000)
plt.colorbar()

# %% [markdown]
# ### 4.4 dynamic picking spots

# %%
dynamic_picked_pts = a._dynamic_picking_spots('unique', _w_dist=1)
# Out:
# + Pick unique spots for by brightness in fov:0, cell:0
# - Save cell_info to: Z:/20180911-IMR90_whole-chr21\Analysis\5x10\fov-0\cell-0\cell_info.pkl
# -- loading existing info from file: Z:/20180911-IMR90_whole-chr21\Analysis\5x10\fov-0\cell-0\cell_info.pkl
# -- information updated in cell_info.pkl: ['picked_unique_spots', 'picked_unique_spots']
# - Writing cell data to file: Z:/20180911-IMR90_whole-chr21\Analysis\5x10\fov-0\cell-0\cell_info.pkl

# %%
distmaps = a._generate_distance_map('unique',_limits=[100,900])
# Out:
# ++ generate unique dist-map for fov:0, cell:0, chrom:0
# ++ Make directory: Z:/20180911-IMR90_whole-chr21\Analysis\distmap\Conv_zscan_00
# ++ generate unique dist-map for fov:0, cell:0, chrom:1
# - Save cell_info to: Z:/20180911-IMR90_whole-chr21\Analysis\5x10\fov-0\cell-0\cell_info.pkl
# -- loading existing info from file: Z:/20180911-IMR90_whole-chr21\Analysis\5x10\fov-0\cell-0\cell_info.pkl
# -- information updated in cell_info.pkl: ['unique_distance_map', 'unique_distance_map']
# - Writing cell data to file: Z:/20180911-IMR90_whole-chr21\Analysis\5x10\fov-0\cell-0\cell_info.pkl
